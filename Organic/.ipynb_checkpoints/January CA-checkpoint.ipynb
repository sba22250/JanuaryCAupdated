# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import statistics as stats
from datetime import datetime
import sklearn.preprocessing as preproc

# %%
df=pd.read_csv('ORG_LSTSPEC.csv')

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df
# Out:
#                     DATAFLOW        LAST UPDATE freq           animals unit  \
# 0     ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 1     ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 2     ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 3     ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 4     ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 5     ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 6     ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 7     ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 8     ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 9     ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 10    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 11    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 12    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 13    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 14    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 15    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 16    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 17    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 18    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 19    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 20    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 21    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 22    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 23    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 24    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 25    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 26    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 27    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 28    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 29    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 30    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 31    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 32    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 33    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 34    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 35    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 36    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 37    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 38    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 39    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 40    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 41    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 42    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 43    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 44    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 45    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 46    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 47    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 48    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 49    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 50    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 51    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 52    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 53    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 54    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 55    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 56    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 57    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 58    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 59    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 60    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 61    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 62    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 63    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 64    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 65    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 66    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 67    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 68    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 69    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 70    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 71    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 72    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 73    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 74    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 75    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 76    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 77    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 78    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 79    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 80    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 81    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 82    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 83    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 84    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 85    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 86    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 87    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 88    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 89    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 90    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 91    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 92    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 93    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 94    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 95    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 96    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 97    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 98    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 99    ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 100   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 101   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 102   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 103   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 104   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 105   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 106   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 107   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 108   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 109   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 110   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 111   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 112   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 113   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 114   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 115   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 116   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 117   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 118   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 119   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 120   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 121   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 122   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 123   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 124   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 125   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 126   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 127   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 128   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 129   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 130   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 131   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 132   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 133   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 134   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 135   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 136   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 137   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 138   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 139   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 140   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 141   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 142   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 143   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 144   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 145   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 146   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 147   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 148   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 149   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 150   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 151   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 152   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 153   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 154   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 155   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 156   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 157   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 158   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 159   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 160   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 161   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 162   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 163   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 164   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 165   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 166   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 167   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 168   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 169   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 170   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 171   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 172   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 173   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 174   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 175   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 176   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 177   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 178   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 179   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 180   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 181   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 182   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 183   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 184   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 185   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 186   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 187   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 188   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 189   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 190   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 191   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 192   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 193   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 194   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 195   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 196   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 197   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 198   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 199   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 200   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 201   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 202   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 203   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 204   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 205   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 206   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 207   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 208   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 209   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   HD
# 210   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A1100   NR
# 211   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 212   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 213   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 214   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 215   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 216   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 217   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 218   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 219   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 220   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 221   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 222   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 223   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 224   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 225   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 226   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 227   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 228   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 229   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 230   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 231   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 232   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 233   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 234   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 235   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 236   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 237   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 238   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 239   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 240   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 241   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 242   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 243   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 244   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 245   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 246   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 247   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 248   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 249   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 250   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 251   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 252   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 253   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 254   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 255   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 256   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 257   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 258   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 259   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 260   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 261   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 262   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 263   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 264   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 265   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 266   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 267   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 268   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 269   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 270   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 271   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 272   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 273   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 274   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 275   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 276   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 277   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 278   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 279   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 280   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 281   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 282   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 283   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 284   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 285   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 286   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 287   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 288   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 289   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 290   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 291   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 292   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 293   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 294   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 295   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 296   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 297   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 298   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 299   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 300   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 301   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 302   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 303   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 304   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 305   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 306   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 307   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 308   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 309   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 310   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 311   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 312   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 313   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 314   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 315   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 316   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 317   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 318   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 319   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 320   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 321   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 322   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 323   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 324   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 325   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 326   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 327   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 328   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 329   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 330   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 331   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 332   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 333   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 334   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 335   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 336   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 337   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 338   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 339   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 340   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 341   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 342   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 343   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 344   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 345   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 346   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 347   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 348   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 349   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 350   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 351   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 352   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 353   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 354   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 355   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 356   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 357   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 358   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 359   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 360   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 361   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 362   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 363   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 364   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 365   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 366   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 367   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 368   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 369   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 370   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 371   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 372   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 373   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 374   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 375   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 376   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 377   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 378   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 379   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 380   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 381   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 382   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 383   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 384   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 385   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 386   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 387   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 388   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 389   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 390   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 391   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 392   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 393   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 394   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 395   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 396   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 397   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 398   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 399   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 400   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 401   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 402   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 403   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 404   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 405   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 406   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 407   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 408   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 409   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 410   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 411   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 412   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 413   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 414   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 415   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 416   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 417   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 418   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 419   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 420   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 421   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 422   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 423   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 424   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 425   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 426   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 427   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 428   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 429   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 430   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 431   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 432   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 433   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 434   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 435   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 436   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 437   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 438   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 439   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 440   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 441   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 442   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 443   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 444   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 445   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 446   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 447   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 448   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 449   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 450   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 451   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 452   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 453   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 454   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 455   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 456   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 457   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 458   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 459   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 460   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 461   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 462   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 463   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 464   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 465   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 466   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 467   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 468   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 469   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 470   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 471   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 472   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 473   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 474   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 475   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 476   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 477   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 478   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 479   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 480   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 481   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 482   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 483   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 484   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 485   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 486   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 487   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 488   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 489   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 490   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 491   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 492   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 493   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 494   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 495   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 496   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 497   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 498   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 499   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 500   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 501   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 502   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 503   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 504   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 505   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 506   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 507   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 508   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 509   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 510   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 511   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 512   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 513   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 514   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 515   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 516   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 517   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 518   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 519   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 520   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 521   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 522   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 523   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 524   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 525   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 526   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 527   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 528   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 529   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 530   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 531   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 532   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 533   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 534   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 535   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 536   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 537   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 538   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 539   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 540   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 541   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 542   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 543   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 544   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 545   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 546   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   HD
# 547   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A             A2000   NR
# 548   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 549   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 550   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 551   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 552   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 553   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 554   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 555   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 556   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 557   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 558   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 559   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 560   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 561   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 562   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 563   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 564   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 565   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 566   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 567   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 568   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 569   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 570   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 571   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 572   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 573   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 574   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 575   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 576   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 577   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 578   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 579   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 580   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 581   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 582   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 583   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 584   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 585   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 586   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 587   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 588   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 589   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 590   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 591   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 592   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 593   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 594   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 595   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 596   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 597   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 598   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 599   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 600   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 601   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 602   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 603   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 604   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# 605   ESTAT:ORG_LSTSPEC(1.0)  02/12/22 23:00:00    A            A2000B   HD
# ...
# 5047         DK         2018        315      NaN
# 5048         DK         2019        631      NaN
# 5049         DK         2020        177      NaN
# 5050         EE         2012        917      NaN
# 5051         EE         2013       1131      NaN
# 5052         EE         2014       1684      NaN
# 5053         EE         2015       1139      NaN
# 5054         EE         2016       2189      NaN
# 5055         EE         2017       2771      NaN
# 5056         EE         2018       2384      NaN
# 5057         EE         2019       2530      NaN
# 5058         EE         2020       2899      NaN
# 5059         ES         2012      50823      NaN
# 5060         ES         2013      50822      NaN
# 5061         ES         2014      48470      NaN
# 5062         ES         2015      58253      NaN
# 5063         ES         2016      69126      NaN
# 5064         ES         2017      73878      NaN
# 5065         ES         2018      81030      NaN
# 5066         ES         2019      77020      NaN
# 5067         ES         2020      81650      NaN
# 5068         FI         2012       3990      NaN
# 5069         FI         2013       4116      NaN
# 5070         FI         2014       4915      NaN
# 5071         FI         2015       4456      NaN
# 5072         FI         2018       4488      NaN
# 5073         FI         2019       5483        d
# 5074         FI         2020       6190        d
# 5075         FR         2012        734      NaN
# 5076         FR         2013      93157      NaN
# 5077         FR         2014      96478      NaN
# 5078         FR         2015      99740      NaN
# 5079         FR         2016     102767      NaN
# 5080         FR         2017     112292      NaN
# 5081         FR         2018     122545      NaN
# 5082         FR         2019     142000        r
# 5083         FR         2020     179027      NaN
# 5084         HR         2012       2462      NaN
# 5085         HR         2013       2678      NaN
# 5086         HR         2014       3649      NaN
# 5087         HR         2015       3418      NaN
# 5088         HR         2016       2065      NaN
# 5089         HR         2017       1721      NaN
# 5090         HR         2018       2022      NaN
# 5091         HR         2019       2023      NaN
# 5092         HR         2020       2367      NaN
# 5093         IE         2012         58      NaN
# 5094         IE         2013         30      NaN
# 5095         IE         2015          0      NaN
# 5096         IE         2017          0      NaN
# 5097         IE         2019          0      NaN
# 5098         IS         2017          0      NaN
# 5099         IT         2012     128241      NaN
# 5100         IT         2013     140004      NaN
# 5101         IT         2014     146692      NaN
# 5102         IT         2015     195341      NaN
# 5103         LT         2012        806      NaN
# 5104         LT         2013        804      NaN
# 5105         LT         2014        790      NaN
# 5106         LT         2015        790      NaN
# 5107         LT         2016        994      NaN
# 5108         LT         2017       1098      NaN
# 5109         LT         2018        883      NaN
# 5110         LT         2019        902      NaN
# 5111         LT         2020       1092      NaN
# 5112         LU         2012         33      NaN
# 5113         LU         2013         34      NaN
# 5114         LU         2014         44      NaN
# 5115         LU         2015         44      NaN
# 5116         LU         2016         37      NaN
# 5117         LU         2017         47      NaN
# 5118         LU         2018         63      NaN
# 5119         LU         2019         82      NaN
# 5120         LU         2020        116      NaN
# 5121         LV         2012      16701      NaN
# 5122         LV         2013      12036      NaN
# 5123         LV         2014      15888      NaN
# 5124         LV         2015      24167      NaN
# 5125         LV         2016      27482      NaN
# 5126         LV         2017      25863      NaN
# 5127         LV         2018      28090      NaN
# 5128         LV         2019      24279      NaN
# 5129         LV         2020      23541      NaN
# 5130         MK         2013       6148      NaN
# 5131         MK         2014       6172      NaN
# 5132         MK         2015       6104      NaN
# 5133         MK         2016       7880      NaN
# 5134         MK         2017       7664      NaN
# 5135         MK         2018       8138      NaN
# 5136         MK         2019       9061      NaN
# 5137         MK         2020       9829      NaN
# 5138         MT         2012          0      NaN
# 5139         MT         2014          0      NaN
# 5140         MT         2015          0      NaN
# 5141         MT         2016          0      NaN
# 5142         MT         2017          0      NaN
# 5143         MT         2018          0      NaN
# 5144         NO         2012       1454      NaN
# 5145         NO         2013       1376        r
# 5146         NO         2014       1347      NaN
# 5147         NO         2015       1507      NaN
# 5148         NO         2016       1564      NaN
# 5149         NO         2017       1553      NaN
# 5150         NO         2018       1721      NaN
# 5151         NO         2019       1830      NaN
# 5152         NO         2020       1861      NaN
# 5153         PL         2012       1989      NaN
# 5154         PL         2013       1773      NaN
# 5155         PL         2014       1844      NaN
# 5156         PL         2015       2442      NaN
# 5157         PL         2016       1948      NaN
# 5158         PL         2017       2434      NaN
# 5159         PL         2018       2319      NaN
# 5160         PL         2019       2856      NaN
# 5161         PT         2012      32409      NaN
# 5162         PT         2013      33942      NaN
# 5163         PT         2014      47118      NaN
# 5164         PT         2015      55167      NaN
# 5165         PT         2017      55249      NaN
# 5166         PT         2018      42105      NaN
# 5167         PT         2019      53849      NaN
# 5168         PT         2020      48604      NaN
# 5169         RO         2012      85225      NaN
# 5170         RO         2013      81772      NaN
# 5171         RO         2014      81583      NaN
# 5172         RO         2015      79654      NaN
# 5173         RO         2016      86195      NaN
# 5174         RO         2018     138557      NaN
# 5175         RO         2019     175959      NaN
# 5176         RO         2020     170789      NaN
# 5177         RS         2013        603      NaN
# 5178         RS         2014        884      NaN
# 5179         RS         2015        471      NaN
# 5180         RS         2016       1735      NaN
# 5181         RS         2017       2307      NaN
# 5182         RS         2018       3061      NaN
# 5183         RS         2019       9969      NaN
# 5184         RS         2020      12618      NaN
# 5185         SI         2012       1598      NaN
# 5186         SI         2013       1803      NaN
# 5187         SI         2014       1631      NaN
# 5188         SI         2015       1400      NaN
# 5189         SI         2016       1814      NaN
# 5190         SK         2012        371      NaN
# 5191         SK         2013        364      NaN
# 5192         SK         2014        477      NaN
# 5193         SK         2015        354      NaN
# 5194         SK         2016        456      NaN
# 5195         SK         2017        426      NaN
# 5196         SK         2019        439      NaN
# 5197         SK         2020        251      NaN
# 5198         TR         2013      32342      NaN
# 5199         TR         2014      36391      NaN
# 5200         TR         2015      38296      NaN
# 5201         TR         2016      40371      NaN
# 5202         TR         2017      48153      NaN
# 5203         TR         2018      51742      NaN
# 5204         TR         2019      50100      NaN
# 5205         TR         2020      89128      NaN
# 5206         AT         2015       8109      NaN
# 5207         AT         2016       9307      NaN
# 5208         AT         2017       8377      NaN
# 5209         AT         2018       9563      NaN
# 5210         AT         2019      10184      NaN
# 5211         AT         2020      10657      NaN
# 5212         BE         2013        266      NaN
# 5213         BE         2014        264      NaN
# 5214         BE         2015        228      NaN
# 5215         BE         2016      10286      NaN
# 5216         BE         2017        290      NaN
# 5217         BE         2018        307      NaN
# 5218         BE         2019        345      NaN
# 5219         BE         2020        361      NaN
# 5220         BG         2012          0      NaN
# 5221         BG         2014          0      NaN
# 5222         BG         2015         20      NaN
# 5223         BG         2016        120      NaN
# 5224         BG         2017          0      NaN
# 5225         BG         2018          0      NaN
# 5226         BG         2019          0      NaN
# 5227         BG         2020          0      NaN
# 5228         CH         2012       2117      NaN
# 5229         CH         2013       2338      NaN
# 5230         CH         2014       2599      NaN
# 5231         CH         2015       2869      NaN
# 5232         CH         2016       3040      NaN
# 5233         CH         2017       3296      NaN
# 5234         CH         2018       3348      NaN
# 5235         CH         2019       3697      NaN
# 5236         CH         2020       3693      NaN
# 5237         CY         2012          0      NaN
# 5238         CY         2013          0      NaN
# 5239         CY         2014          0      NaN
# 5240         CY         2015          0      NaN
# 5241         CY         2018          0      NaN
# 5242         CY         2019          0      NaN
# 5243         CY         2020          0      NaN
# 5244         CZ         2012        157      NaN
# 5245         CZ         2013        183      NaN
# 5246         CZ         2014         75      NaN
# 5247         CZ         2015         86      NaN
# 5248         CZ         2016        127      NaN
# 5249         CZ         2017        203      NaN
# 5250         CZ         2018          0      NaN
# 5251         CZ         2020        100      NaN
# 5252         DK         2014          0      NaN
# 5253         DK         2015        524      NaN
# 5254         DK         2016        826      NaN
# 5255         DK         2017        722      NaN
# 5256         DK         2018        427      NaN
# 5257         DK         2019        586      NaN
# 5258         DK         2020        672      NaN
# 5259         EE         2017          0      NaN
# 5260         EE         2018          0      NaN
# 5261         EE         2019          9      NaN
# 5262         EE         2020         13      NaN
# 5263         ES         2012          0      NaN
# 5264         ES         2013         25      NaN
# 5265         ES         2014        500      NaN
# 5266         ES         2015     209506      NaN
# 5267         FI         2018         52      NaN
# 5268         FI         2019         48      NaN
# 5269         FI         2020         36      NaN
# 5270         FR         2014    5988060      NaN
# 5271         FR         2016    8106794      NaN
# 5272         FR         2017    8034922      NaN
# 5273         FR         2018    9846460      NaN
# 5274         FR         2019    9106599      NaN
# 5275         HR         2013      13472      NaN
# 5276         HR         2015        237      NaN
# 5277         HR         2016      10400      NaN
# 5278         HR         2018      10100      NaN
# 5279         IE         2015        771      NaN
# 5280         IE         2017       1038      NaN
# 5281         IE         2019        767      NaN
# 5282         IE         2020        861      NaN
# 5283         IT         2013       3766      NaN
# 5284         IT         2014       3812      NaN
# 5285         IT         2015      32154      NaN
# 5286         LT         2013       1312      NaN
# 5287         LT         2014       1776      NaN
# 5288         LT         2015       1238      NaN
# 5289         LT         2016          0      NaN
# 5290         LT         2017          0      NaN
# 5291         LT         2018         17      NaN
# 5292         LT         2019       1051      NaN
# 5293         LT         2020        919      NaN
# 5294         LU         2012          0      NaN
# 5295         LU         2013          0      NaN
# 5296         LU         2014          0      NaN
# 5297         LU         2015          4      NaN
# 5298         LU         2016          3      NaN
# 5299         LU         2017          0      NaN
# 5300         LU         2018          1      NaN
# 5301         LU         2019          4      NaN
# 5302         LU         2020          4      NaN
# 5303         MK         2013          0      NaN
# 5304         MK         2014          0      NaN
# 5305         MT         2012          0      NaN
# 5306         MT         2014          0      NaN
# 5307         MT         2015          0      NaN
# 5308         MT         2016          0      NaN
# 5309         MT         2017          0      NaN
# 5310         MT         2018          0      NaN
# 5311         NL         2012          0      NaN
# 5312         NL         2013          0      NaN
# 5313         NL         2014          0      NaN
# 5314         NO         2020          0      NaN
# 5315         PL         2013       4742      NaN
# 5316         PL         2014       5399      NaN
# 5317         PL         2015       4485      NaN
# 5318         PL         2016       4219      NaN
# 5319         PL         2017       4440      NaN
# 5320         PL         2018       3487      NaN
# 5321         PL         2019       3747      NaN
# 5322         PT         2013          0      NaN
# 5323         PT         2014          0      NaN
# 5324         PT         2017          0      NaN
# 5325         PT         2018          0      NaN
# 5326         PT         2019          0      NaN
# 5327         PT         2020          0      NaN
# 5328         RO         2012       5217      NaN
# 5329         RO         2013       4878      NaN
# 5330         RO         2014       2667      NaN
# 5331         RO         2015       4515      NaN
# 5332         RO         2016       3353      NaN
# 5333         RO         2017       1791      NaN
# 5334         RO         2019       1893      NaN
# 5335         RO         2020       1444      NaN
# 5336         RS         2015          0      NaN
# 5337         RS         2017         47      NaN
# 5338         RS         2018          0      NaN
# 5339         RS         2019          0      NaN
# 5340         RS         2020          0      NaN
# 5341         SI         2012       1589      NaN
# 5342         SI         2013       1688      NaN
# 5343         SI         2014       1896      NaN
# 5344         SI         2015       1973      NaN
# 5345         SI         2016       1984      NaN
# 5346         SK         2012         13      NaN
# 5347         SK         2013         17      NaN
# 5348         SK         2014          9      NaN
# 5349         SK         2015          7      NaN
# 5350         SK         2016         19      NaN
# 5351         SK         2017          7      NaN
# 5352         SK         2019         21      NaN
# 5353         SK         2020         14      NaN
# 5354         TR         2014          0      NaN
# 5355         TR         2015          0      NaN
# 5356         TR         2016          0      NaN
# 5357         TR         2017          0      NaN
# 5358         TR         2018          0      NaN
# 5359         TR         2019          0      NaN

# %%
df['unit'].unique()
# Out:
# array(['HD', 'NR'], dtype=object)

# %%
#df['unit'] =(df['unit'] == 'HD').astype(int)

# %%
#df

# %%
#df.groupby(['geo']).mean()

# %%
#df.groupby('geo')['geo'].agg('count')

# %%
#df.groupby('animals')['animals'].agg('count')

# %%
#df.rename(index= {"A1100":"Live horses","A2000":"Live bovine animals","A2000B":"Bovine animals for slaughter","A2300F":"Dairy cows","A2900":"Other bovine animals","A3100":"Live swine, domestic species","A3120":"Breeding sows, live weight 50 kg or over","A3130":"Other pigs","A3132":"Fattening pigs, live weight 50 kg or over","A4100":"Live sheep","A4110":"Ewes and ewe-lambs, breeding females","A4110K":"Ewes and ewe-lambs put to the ram","A4120":"Other sheep","A4200":"Live goats","A4210":"Goats, breeding females","A4220":"Other goats","A5000":"Live poultry","A5000X5110O_5140":"Live poultry excluding laying hens and broilers","A5110O":"Laying hens","A5110OH":"Laying hens (producing eggs for consumption)","A5140":"Broilers","A6110":"Rabbits","A6710R":"Bees (hives)","A6900":"Other live animals"}, inplace = True)
#df

# %%
#df.dtypes

# %%
df = df.drop(['DATAFLOW','LAST UPDATE', 'freq','OBS_FLAG'], axis =1)
df.head(5)
# Out:
#   animals unit geo  TIME_PERIOD  OBS_VALUE
# 0   A1100   HD  AT         2015      15697
# 1   A1100   HD  AT         2016      18161
# 2   A1100   HD  AT         2017      17273
# 3   A1100   HD  AT         2018      17752
# 4   A1100   HD  AT         2019      18678

# %%
df.describe()
# Out:
#        TIME_PERIOD     OBS_VALUE
# count  5360.000000  5.360000e+03
# mean   2016.193097  2.442407e+05
# std       2.609682  1.446925e+06
# min    2012.000000  0.000000e+00
# 25%    2014.000000  5.230000e+02
# 50%    2016.000000  6.562500e+03
# 75%    2018.000000  5.098275e+04
# max    2021.000000  4.266108e+07

# %%
df.count()
# Out:
# animals        5360
# unit           5360
# geo            5360
# TIME_PERIOD    5360
# OBS_VALUE      5360
# dtype: int64

# %%
#df['geo'].value_counts()

# %%
#df =df.groupby('geo', axis =0).sum()
#print(df)

# %%
#df['TIME_PERIOD'].value_counts()

# %%
df.shape
# Out:
# (5360, 5)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# animals        0
# unit           0
# geo            0
# TIME_PERIOD    0
# OBS_VALUE      0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
import seaborn as sns
sns.distplot(df["OBS_VALUE"]);

# %%
sns.jointplot(x='TIME_PERIOD', y='OBS_VALUE', data=df);

# %%
sns.distplot()

# %% [markdown]
# # Outliers
# Outliers are the datapoint which are data errors or sometimes they are not data error but they just represent the extreme variations in the dataset so although they are valid itmakes sense to remove them otherwise they can create some issues later. we can use different techiques to tackle with them like using standard deviation or we can use simple domain knowledge.

# %%
sns.boxplot(x=df["OBS_VALUE"])
# Out:
# <AxesSubplot:xlabel='OBS_VALUE'>

# %% [markdown]
# Q1 = df.quantile(0.25)
# Q3 = df.quantile(0.75)
# IQR = Q3-Q1
# print(IQR)

# %% [markdown]
# df = df[~((df < (Q1-1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df.shape
# Out:
# (5360, 5)

# %%
# Remove column name 'A'
#df=df.drop(['OBS_FLAG'], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5360 entries, 0 to 5359
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   animals      5360 non-null   object
#  1   unit         5360 non-null   object
#  2   geo          5360 non-null   object
#  3   TIME_PERIOD  5360 non-null   int64
#  4   OBS_VALUE    5360 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 209.5+ KB

# %%
df.hist(column='OBS_VALUE', bins =20)
# Out:
# array([[<AxesSubplot:title={'center':'OBS_VALUE'}>]], dtype=object)

# %%
ax=sns.barplot(x="TIME_PERIOD", y="OBS_VALUE", data=df )

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5360 entries, 0 to 5359
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   animals      5360 non-null   object
#  1   unit         5360 non-null   object
#  2   geo          5360 non-null   object
#  3   TIME_PERIOD  5360 non-null   int64
#  4   OBS_VALUE    5360 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 209.5+ KB

# %% [markdown]
# creating multi plots on the same canvas.

# %%
fig, b = plt.subplots(figsize=(15,6))
b = plt.bar(df['geo'], df['OBS_VALUE'])

# %%
df.geo.value_counts().nlargest(40).plot(kind="bar", figsize=(10,5))
plt.title("Number of oberved value by Country")
plt.ylabel("OBS_VALUE")
plt.xlabel("geo");

# %% [markdown]
# plt.figure() is
# object oriented method and this is going to be much better.
# The main idea in using the more formal object oriented method is to create figure objects and then just call methods off of this. Let me go in and show you what I mean by that.(20 is width and 10 is height

# %%
plt.figure(figsize=(20,10))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#              TIME_PERIOD  OBS_VALUE
# TIME_PERIOD     1.000000   0.020557
# OBS_VALUE       0.020557   1.000000

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df["TIME_PERIOD"], df["OBS_VALUE"])
ax.set_xlabel("TIME_PERIOD")
ax.set_ylabel("OBS_VALUE")
plt.show()

# %%
df.describe().transpose()
# Out:
#               count           mean           std     min     25%     50%  \
# TIME_PERIOD  5360.0    2016.193097  2.609682e+00  2012.0  2014.0  2016.0
# OBS_VALUE    5360.0  244240.666791  1.446925e+06     0.0   523.0  6562.5
#
#                   75%         max
# TIME_PERIOD   2018.00      2021.0
# OBS_VALUE    50982.75  42661084.0

# %% [markdown]
# ## Statistics

# %%
from numpy.random import randn
np.random.seed(101)

# %%
import statistics
from scipy.stats import poisson

x = poisson.rvs(mu = 2.442407e+05, size = 101)
plt.axvline(2.442407e+05, color = 'red')
ax = sns.distplot(x, kde= True, color ='blue', hist_kws ={"linewidth":25, 'alpha':1})
ax.set(xlabel='poisson', ylabel='Frequency')
plt.show()

# %%
import statistics
from scipy.stats import norm
norm.pdf(1, loc = 2.442407e+05, scale=1.446925e+06 )
# Out:
# 2.718171385602083e-07

# %%
fig, ax = plt.subplots(figsize=(15,6))
ax = sns.histplot(df['geo'],  kde=True, color ='Purple', bins=50)
ax.set(xlabel='geo', ylabel='OBS_VALUE', title ='Organic meat per country')
# Out:
# [Text(0.5, 0, 'geo'),
#  Text(0, 0.5, 'OBS_VALUE'),
#  Text(0.5, 1.0, 'Organic meat per country')]

# %%
#sns.histplot(df)

# %%
fig, g = plt.subplots(figsize=(20,10))
g=sns.histplot(data=df, x='geo', hue ="animals", multiple="stack")
